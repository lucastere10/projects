# %% [markdown]
# # Packages Instalations

# %% [markdown]
# ### Upgrade pip

# %%
#upgrade pip
! pip install --user --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\lucas\anaconda3\lib\site-packages (22.0.4)

# %% [markdown]
# ### Pandas and Numpy

# %%
#Pandas and Numpy
! pip install pandas
! pip install numpy
# Out:
# Requirement already satisfied: pandas in c:\users\lucas\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\lucas\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\lucas\anaconda3\lib\site-packages (1.20.3)

# %% [markdown]
# ### Visualization

# %%
#Visualization
! pip install seaborn
! python -m pip install -U matplotlib
# Out:
# Requirement already satisfied: seaborn in c:\users\lucas\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\lucas\anaconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\lucas\anaconda3\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\lucas\anaconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\lucas\anaconda3\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six in c:\users\lucas\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\lucas\anaconda3\lib\site-packages (3.4.3)
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp39-cp39-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib) (21.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six in c:\users\lucas\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Uninstalling matplotlib-3.4.3:
#       Successfully uninstalled matplotlib-3.4.3
# Successfully installed matplotlib-3.5.1

# %% [markdown]
# ### Plotly & Cufflinks

# %%
#plotly & cufflinks
! pip install plotly==5.7.0
! pip install chart_studio
! pip install cufflinks

#requires further instalations as follows
! pip install "jupyterlab>=3" "ipywidgets>=7.6"
! pip install "notebook>=5.3" "ipywidgets>=7.5"
! pip install jupyter-dash
# Out:
# Requirement already satisfied: plotly==5.7.0 in c:\users\lucas\anaconda3\lib\site-packages (5.7.0)
# Requirement already satisfied: six in c:\users\lucas\anaconda3\lib\site-packages (from plotly==5.7.0) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from plotly==5.7.0) (8.0.1)
# Requirement already satisfied: chart_studio in c:\users\lucas\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: six in c:\users\lucas\anaconda3\lib\site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: requests in c:\users\lucas\anaconda3\lib\site-packages (from chart_studio) (2.26.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\lucas\anaconda3\lib\site-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: plotly in c:\users\lucas\anaconda3\lib\site-packages (from chart_studio) (5.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from requests->chart_studio) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\anaconda3\lib\site-packages (from requests->chart_studio) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lucas\anaconda3\lib\site-packages (from requests->chart_studio) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas\anaconda3\lib\site-packages (from requests->chart_studio) (3.2)
# Requirement already satisfied: cufflinks in c:\users\lucas\anaconda3\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\lucas\anaconda3\lib\site-packages (from cufflinks) (1.20.3)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\lucas\anaconda3\lib\site-packages (from cufflinks) (7.29.0)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\lucas\anaconda3\lib\site-packages (from cufflinks) (1.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from cufflinks) (7.6.5)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\lucas\anaconda3\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\lucas\anaconda3\lib\site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from cufflinks) (58.0.4)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\lucas\anaconda3\lib\site-packages (from cufflinks) (5.7.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.20)
# Requirement already satisfied: pygments in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.10.0)
# Requirement already satisfied: backcall in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: decorator in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.0)
# Requirement already satisfied: colorama in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.0.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lucas\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\lucas\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\lucas\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.8.1)
# Requirement already satisfied: wcwidth in c:\users\lucas\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.4.5)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (21.2.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (228)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.11.0)
# Requirement already satisfied: nbconvert in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.1.0)
# Requirement already satisfied: jinja2 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.8.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\lucas\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.14.6)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lucas\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.0.1)
# Requirement already satisfied: bleach in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.0.0)
# Requirement already satisfied: defusedxml in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: testpath in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.4.3)
# Requirement already satisfied: pycparser in c:\users\lucas\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.20)
# Requirement already satisfied: async-generator in c:\users\lucas\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\lucas\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: packaging in c:\users\lucas\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.0)
# Requirement already satisfied: webencodings in c:\users\lucas\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.0.4)
# Requirement already satisfied: jupyterlab>=3 in c:\users\lucas\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: ipywidgets>=7.6 in c:\users\lucas\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: jupyter-server~=1.4 in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab>=3) (1.4.1)
# Requirement already satisfied: ipython in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab>=3) (7.29.0)
# Requirement already satisfied: packaging in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab>=3) (21.0)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab>=3) (6.1)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab>=3) (0.2.6)
# Requirement already satisfied: jinja2>=2.1 in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab>=3) (2.11.3)
# Requirement already satisfied: jupyterlab-server~=2.3 in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab>=3) (2.8.2)
# Requirement already satisfied: jupyter-core in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab>=3) (4.8.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.6) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.6) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.6) (5.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.6) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.6) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.6) (6.4.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6) (1.4.1)
# Requirement already satisfied: backcall in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (58.0.4)
# Requirement already satisfied: colorama in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.4.4)
# Requirement already satisfied: decorator in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (5.1.0)
# Requirement already satisfied: pygments in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyterlab>=3) (0.7.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lucas\anaconda3\lib\site-packages (from jinja2>=2.1->jupyterlab>=3) (2.0.1)
# Requirement already satisfied: prometheus-client in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (0.11.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (228)
# Requirement already satisfied: anyio>=2.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (2.2.0)
# Requirement already satisfied: nbconvert in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (0.9.4)
# Requirement already satisfied: Send2Trash in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3) (22.2.1)
# Requirement already satisfied: requests in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (2.26.0)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (3.2.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (0.3)
# Requirement already satisfied: json5 in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (0.9.6)
# Requirement already satisfied: babel in c:\users\lucas\anaconda3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3) (2.9.1)
# Requirement already satisfied: notebook<7 in c:\users\lucas\anaconda3\lib\site-packages (from nbclassic~=0.2->jupyterlab>=3) (6.4.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from packaging->jupyterlab>=3) (3.0.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lucas\anaconda3\lib\site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\lucas\anaconda3\lib\site-packages (from anyio>=2.0.2->jupyter-server~=1.4->jupyterlab>=3) (3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lucas\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyterlab>=3) (0.8.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6) (2.8.2)
# Requirement already satisfied: argon2-cffi in c:\users\lucas\anaconda3\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab>=3) (20.1.0)
# Requirement already satisfied: wcwidth in c:\users\lucas\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=3) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\lucas\anaconda3\lib\site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab>=3) (0.5.7)
# Requirement already satisfied: pytz>=2015.7 in c:\users\lucas\anaconda3\lib\site-packages (from babel->jupyterlab-server~=2.3->jupyterlab>=3) (2021.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.1.2)
# Requirement already satisfied: bleach in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (4.0.0)
# Requirement already satisfied: testpath in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lucas\anaconda3\lib\site-packages (from requests->jupyterlab-server~=2.3->jupyterlab>=3) (1.26.7)
# Requirement already satisfied: nest-asyncio in c:\users\lucas\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\lucas\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (1.10)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from argon2-cffi->notebook<7->nbclassic~=0.2->jupyterlab>=3) (1.14.6)
# Requirement already satisfied: webencodings in c:\users\lucas\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab>=3) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\lucas\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook<7->nbclassic~=0.2->jupyterlab>=3) (2.20)
# Requirement already satisfied: notebook>=5.3 in c:\users\lucas\anaconda3\lib\site-packages (6.4.5)
# Requirement already satisfied: ipywidgets>=7.5 in c:\users\lucas\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (4.8.1)
# Requirement already satisfied: nbformat in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (5.1.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (0.9.4)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (5.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (6.1)
# Requirement already satisfied: prometheus-client in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (0.11.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (22.2.1)
# Requirement already satisfied: ipykernel in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (6.4.1)
# Requirement already satisfied: argon2-cffi in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (20.1.0)
# Requirement already satisfied: jinja2 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (2.11.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (6.1.12)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (1.8.0)
# Requirement already satisfied: ipython-genutils in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (0.2.0)
# Requirement already satisfied: nbconvert in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=5.3) (6.1.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.5) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.5) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.5) (7.29.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel->notebook>=5.3) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel->notebook>=5.3) (1.4.1)
# Requirement already satisfied: pygments in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (58.0.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (3.0.20)
# Requirement already satisfied: colorama in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.18.0)
# Requirement already satisfied: decorator in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (5.1.0)
# Requirement already satisfied: backcall in c:\users\lucas\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.3) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=5.3) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\lucas\anaconda3\lib\site-packages (from nbformat->notebook>=5.3) (3.2.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\lucas\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.3) (0.5.7)
# Requirement already satisfied: six in c:\users\lucas\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.3) (1.16.0)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.3) (1.14.6)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lucas\anaconda3\lib\site-packages (from jinja2->notebook>=5.3) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.3)
# Requirement already satisfied: testpath in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (0.8.4)
# Requirement already satisfied: bleach in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=5.3) (4.0.0)
# Requirement already satisfied: pycparser in c:\users\lucas\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=5.3) (2.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lucas\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5) (0.8.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.3) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.3) (0.18.0)
# Requirement already satisfied: async-generator in c:\users\lucas\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=5.3) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\lucas\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=5.3) (1.5.1)
# Requirement already satisfied: wcwidth in c:\users\lucas\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5) (0.2.5)
# Requirement already satisfied: packaging in c:\users\lucas\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=5.3) (21.0)
# Requirement already satisfied: webencodings in c:\users\lucas\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=5.3) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=5.3) (3.0.4)
# Requirement already satisfied: jupyter-dash in c:\users\lucas\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: ipython in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-dash) (7.29.0)
# Requirement already satisfied: ipykernel in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-dash) (6.4.1)
# Requirement already satisfied: flask in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-dash) (1.1.2)
# Requirement already satisfied: retrying in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: dash in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-dash) (2.2.0)
# Requirement already satisfied: requests in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-dash) (2.26.0)
# Requirement already satisfied: ansi2html in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-dash) (1.7.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.7.0)
# Requirement already satisfied: flask-compress in c:\users\lucas\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.11)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\lucas\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.0.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\lucas\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\lucas\anaconda3\lib\site-packages (from flask->jupyter-dash) (8.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\lucas\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: ipython-genutils in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.2.0)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.1.0)
# Requirement already satisfied: pygments in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyter-dash) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.20)
# Requirement already satisfied: decorator in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.1.0)
# Requirement already satisfied: colorama in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: backcall in c:\users\lucas\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas\anaconda3\lib\site-packages (from requests->jupyter-dash) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lucas\anaconda3\lib\site-packages (from requests->jupyter-dash) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\anaconda3\lib\site-packages (from requests->jupyter-dash) (2021.10.8)
# Requirement already satisfied: six>=1.7.0 in c:\users\lucas\anaconda3\lib\site-packages (from retrying->jupyter-dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lucas\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lucas\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (4.8.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: wcwidth in c:\users\lucas\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: brotli in c:\users\lucas\anaconda3\lib\site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter-dash) (228)

# %% [markdown]
# ### GeoPandas

# %%
#Necessary Packages
! pip install rtree
! pip install shapely
! pip install pyproj
#Geopandas
! pip install geopandas
# Out:
# Requirement already satisfied: rtree in c:\users\lucas\anaconda3\lib\site-packages (0.9.7)
# Requirement already satisfied: shapely in c:\users\lucas\anaconda3\lib\site-packages (1.8.1.post1)
# Requirement already satisfied: pyproj in c:\users\lucas\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: certifi in c:\users\lucas\anaconda3\lib\site-packages (from pyproj) (2021.10.8)
# Collecting geopandas
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from geopandas) (3.3.0)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# ### ScikiLearn

# %%
#ScikiLearn
! pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lucas\anaconda3\lib\site-packages (0.24.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp39-cp39-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lucas\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\lucas\anaconda3\lib\site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from scikit-learn) (1.7.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
# Successfully installed scikit-learn-1.0.2

# %% [markdown]
# ### NLP

# %%
#NLTK
# !pip install -U nltk
#textblob
! pip install -U textblob
! python -m pip install pillow
#wordcloud
! pip install wordcloud
# Out:
# Requirement already satisfied: nltk in c:\users\lucas\anaconda3\lib\site-packages (3.6.5)
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\lucas\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\lucas\anaconda3\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lucas\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: click in c:\users\lucas\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: colorama in c:\users\lucas\anaconda3\lib\site-packages (from click->nltk) (0.4.4)
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.6.5
#     Uninstalling nltk-3.6.5:
#       Successfully uninstalled nltk-3.6.5
# Successfully installed nltk-3.7
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      -------------------------------------- 636.8/636.8 KB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.1 in c:\users\lucas\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: click in c:\users\lucas\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: joblib in c:\users\lucas\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lucas\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\lucas\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: colorama in c:\users\lucas\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Requirement already satisfied: pillow in c:\users\lucas\anaconda3\lib\site-packages (8.4.0)
# Collecting wordcloud
#   Downloading wordcloud-1.8.1.tar.gz (220 kB)
#      -------------------------------------- 220.7/220.7 KB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.1 in c:\users\lucas\anaconda3\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: pillow in c:\users\lucas\anaconda3\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in c:\users\lucas\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six in c:\users\lucas\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py): started
#   Building wheel for wordcloud (setup.py): finished with status 'error'
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# Installing collected packages: wordcloud
#   Running setup.py install for wordcloud: started
#   Running setup.py install for wordcloud: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#   UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#   set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#   running build_ext
#   building 'wordcloud.query_integral_image' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for wordcloud
#   error: subprocess-exited-with-error
#
#   Running setup.py install for wordcloud did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   running install
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#   UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#   set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#   running build_ext
#   building 'wordcloud.query_integral_image' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# wordcloud
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %% [markdown]
# ### Others

# %%
#Yellowbrick for visualization (elbow method)
! pip install yellowbrick
#Treemaps vizualizer squarefy
! pip install squarify
#Pycaret
! pip install pycaret[full]
# Python library to read/write Excel 2010 xlsx/xlsm/xltx/xltm files.
! pip install openpyxl
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.4-py3-none-any.whl (274 kB)
#      -------------------------------------- 274.2/274.2 KB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.0 in c:\users\lucas\anaconda3\lib\site-packages (from yellowbrick) (1.20.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from yellowbrick) (1.7.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from yellowbrick) (1.0.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from yellowbrick) (3.5.1)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\lucas\anaconda3\lib\site-packages (from yellowbrick) (0.10.0)
# Requirement already satisfied: six in c:\users\lucas\anaconda3\lib\site-packages (from cycler>=0.10.0->yellowbrick) (1.16.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (21.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lucas\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.0)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.4
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3
# Collecting pycaret[full]
#   Downloading pycaret-2.3.6-py3-none-any.whl (301 kB)
#      -------------------------------------- 301.5/301.5 KB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (5.4.0)
# Collecting pyod
#   Downloading pyod-0.9.8.tar.gz (114 kB)
#      -------------------------------------- 114.6/114.6 KB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nltk in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (3.7)
# Collecting umap-learn
#   Downloading umap-learn-0.5.2.tar.gz (86 kB)
#      ---------------------------------------- 86.8/86.8 KB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting wordcloud
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cufflinks>=0.17.0 in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (0.17.3)
# Collecting gensim<4.0.0
#   Downloading gensim-3.8.3.tar.gz (23.4 MB)
#      --------------------------------------- 23.4/23.4 MB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: seaborn in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (0.11.2)
# Requirement already satisfied: pandas in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (1.3.4)
# Requirement already satisfied: textblob in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (0.17.1)
# Collecting mlflow
#   Downloading mlflow-1.24.0-py3-none-any.whl (16.5 MB)
#      --------------------------------------- 16.5/16.5 MB 14.6 MB/s eta 0:00:00
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.7-cp39-cp39-win_amd64.whl (9.4 MB)
#      ---------------------------------------- 9.4/9.4 MB 17.7 MB/s eta 0:00:00
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp39-cp39-win_amd64.whl (31.4 MB)
#      --------------------------------------- 31.4/31.4 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: yellowbrick>=1.0.1 in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (1.4)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 21.2 MB/s eta 0:00:00
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (3.5.1)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 26.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: IPython in c:\users\lucas\anaconda3\lib\site-packages (from pycaret[full]) (7.29.0)
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.11.1-py2.py3-none-any.whl (19 kB)
# Collecting scikit-learn==0.23.2
#   Downloading scikit-learn-0.23.2.tar.gz (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 22.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [617 lines of output]
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-60.9.3-py3-none-any.whl (1.1 MB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Downloading Cython-0.29.28-py2.py3-none-any.whl (983 kB)
#        ------------------------------------- 983.8/983.8 KB 15.5 MB/s eta 0:00:00
#   Collecting numpy==1.17.3
#     Downloading numpy-1.17.3.zip (6.4 MB)
#        ---------------------------------------- 6.4/6.4 MB 25.4 MB/s eta 0:00:00
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting scipy>=0.19.1
#     Downloading scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
#        --------------------------------------- 36.9/36.9 MB 11.9 MB/s eta 0:00:00
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     error: subprocess-exited-with-error
#
#     python setup.py bdist_wheel did not run successfully.
#     exit code: 1
#
#     [268 lines of output]
#     Running from numpy source directory.
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' nÆo ‚ reconhecido como um comando interno
#     ou externo, um programa oper vel ou um arquivo em lotes.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\lucas\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\lucas\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\lucas\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\lucas\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#       NOT AVAILABLE
#
#     C:\Users\lucas\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     error: subprocess-exited-with-error
#
#     python setup.py clean did not run successfully.
#     exit code: 1
#
#     [10 lines of output]
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   Installing collected packages: wheel, setuptools, numpy, Cython, scipy
#     Running setup.py install for numpy: started
#     Running setup.py install for numpy: finished with status 'error'
#     error: subprocess-exited-with-error
#
#     Running setup.py install for numpy did not run successfully.
#     exit code: 1
#
#     [273 lines of output]
#     Running from numpy source directory.
#
#     Note: if you need reliable uninstall behavior, then install
#     with pip instead of using `setup.py install`:
#
#       - `pip install .`       (from a git repo or downloaded source
#                                release)
#       - `pip install numpy`   (last NumPy release on PyPi)
#
#
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' nÆo ‚ reconhecido como um comando interno
#     ou externo, um programa oper vel ou um arquivo em lotes.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\lucas\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\lucas\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\lucas\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\lucas\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\lucas\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\lucas\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\Users\\lucas\\anaconda3\\lib', 'C:\\', 'C:\\Users\\lucas\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\lucas\AppData\Local\Temp\pip-install-mkmc42t5\numpy_ed799a7f4d224d8c85f609348a265113\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#       NOT AVAILABLE
#
#     C:\Users\lucas\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#   error: legacy-install-failure
#
#   Encountered error while trying to install package.
#
#   numpy
#
#   note: This is an issue with the package mentioned above, not pip.
#   hint: See above for output from the failure.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# pip subprocess to install build dependencies did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# ### Pandas Profiling

# %%
! pip install --user pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (3.5.1)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (1.3.4)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (1.9.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (2.26.0)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (0.1.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (1.20.3)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Collecting joblib~=1.0.1
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting phik>=0.11.1
#   Using cached phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (1.7.1)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (4.62.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (2.11.3)
# Requirement already satisfied: markupsafe~=2.0.1 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (2.0.1)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: multimethod>=1.4 in c:\users\lucas\anaconda3\lib\site-packages (from pandas-profiling) (1.8)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\lucas\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (21.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\lucas\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (2.6.3)
# Requirement already satisfied: Pillow in c:\users\lucas\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (8.4.0)
# Collecting imagehash
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucas\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (21.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lucas\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lucas\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\lucas\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.4)
# Requirement already satisfied: six in c:\users\lucas\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\lucas\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.1.1)
# Installing collected packages: joblib, imagehash, visions, phik, missingno, pandas-profiling
# Successfully installed imagehash-4.2.1 joblib-1.0.1 missingno-0.5.1 pandas-profiling-3.1.0 phik-0.12.2 visions-0.7.4
#   WARNING: The script phik_trial.exe is installed in 'C:\Users\lucas\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pandas_profiling.exe is installed in 'C:\Users\lucas\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# ### Streamlit

# %%
! pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.8.1-py2.py3-none-any.whl (10.1 MB)
#      --------------------------------------- 10.1/10.1 MB 25.8 MB/s eta 0:00:00
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      ------------------------------------- 181.2/181.2 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (4.8.1)
# Requirement already satisfied: watchdog in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (2.1.3)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      -------------------------------------- 111.5/111.5 KB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tzlocal
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (1.20.3)
# Collecting protobuf!=3.11,>=3.6.0
#   Downloading protobuf-3.20.1-cp39-cp39-win_amd64.whl (904 kB)
#      ------------------------------------- 904.1/904.1 KB 55.9 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=5.0 in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: packaging in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (21.0)
# Requirement already satisfied: python-dateutil in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Collecting pyarrow
#   Downloading pyarrow-7.0.0-cp39-cp39-win_amd64.whl (16.1 MB)
#      --------------------------------------- 16.1/16.1 MB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.21.0 in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (1.3.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (8.4.0)
# Requirement already satisfied: attrs in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (21.2.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ---------------------------------------- 164.8/164.8 KB ? eta 0:00:00
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      ------------------------------------- 812.8/812.8 KB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: toml in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: click<8.1,>=7.0 in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (8.0.3)
# Collecting cachetools>=4.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: requests in c:\users\lucas\anaconda3\lib\site-packages (from streamlit) (2.26.0)
# Requirement already satisfied: toolz in c:\users\lucas\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: jinja2 in c:\users\lucas\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: entrypoints in c:\users\lucas\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lucas\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: colorama in c:\users\lucas\anaconda3\lib\site-packages (from click<8.1,>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.1/63.1 KB ? eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\lucas\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.6.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lucas\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\lucas\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (6.4.1)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\lucas\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.5)
# Requirement already satisfied: six>=1.5 in c:\users\lucas\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from packaging->streamlit) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\anaconda3\lib\site-packages (from requests->streamlit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas\anaconda3\lib\site-packages (from requests->streamlit) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lucas\anaconda3\lib\site-packages (from requests->streamlit) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from requests->streamlit) (2.0.4)
# Collecting tzdata
#   Downloading tzdata-2022.1-py2.py3-none-any.whl (339 kB)
#      ------------------------------------- 339.5/339.5 KB 21.9 MB/s eta 0:00:00
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\lucas\anaconda3\lib\site-packages (from validators->streamlit) (5.1.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: ipython-genutils in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.29.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lucas\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: setuptools in c:\users\lucas\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (58.0.4)
# Requirement already satisfied: backcall in c:\users\lucas\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\lucas\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\lucas\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.0)
# Requirement already satisfied: pygments in c:\users\lucas\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.10.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lucas\anaconda3\lib\site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lucas\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (228)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.1.0)
# Requirement already satisfied: argon2-cffi in c:\users\lucas\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: wcwidth in c:\users\lucas\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\lucas\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.6)
# Requirement already satisfied: defusedxml in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.3)
# Requirement already satisfied: testpath in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: bleach in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lucas\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: pycparser in c:\users\lucas\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: nest-asyncio in c:\users\lucas\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\lucas\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: webencodings in c:\users\lucas\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=4833fe3b965e87e7cb5d86e7f6932675277fcb31f487bfa8b5282f7932afd051
#   Stored in directory: c:\users\lucas\appdata\local\pip\cache\wheels\50\93\f8\4f0a42a03a06626d675f13907b6982ad5ecff383530af5a900
# Successfully built blinker
# Installing collected packages: blinker, validators, tzdata, smmap, semver, pympler, pyarrow, protobuf, cachetools, pytz-deprecation-shim, gitdb, tzlocal, gitpython, altair, pydeck, streamlit
# Successfully installed altair-4.2.0 blinker-1.4 cachetools-5.0.0 gitdb-4.0.9 gitpython-3.1.27 protobuf-3.20.1 pyarrow-7.0.0 pydeck-0.7.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 semver-2.13.0 smmap-5.0.0 streamlit-1.8.1 tzdata-2022.1 tzlocal-4.2 validators-0.18.2
